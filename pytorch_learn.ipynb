# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaSinghDevs/pytorch-learn/blob/main/pytorch_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %% [markdown]
# ### Tensors

# %%
torch.tensor([1,2,3]) + torch.ones(3)
# Out:
# tensor([2., 3., 4.])

# %% [markdown]
# ### Modules of pytorch

# %%
# Modules are building blocks

import torch.nn as nn

class MyModel(nn.module):
  # INIT FUNCTION (CONSTRUCTOR : defines and describes the architecture of NN diagram )
  # like the input, middle, output layers, number of nodes and stuff

  def __init__(self):
    self.hidden = nn.Linear(3,4) #telling that we need just a linear  layer
    self.output = nn.Linear( 4, 1) # first number is of current layers noce, rest is of output


  # FORWARD FUNCTION (Take in some arbitrary data pointsx1,x2,x2,x3 , then return  model output after  the operaations )

  def forward(self,x):
    hidden_out = self.hidden(x())
    return self.output(hidden_output)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
